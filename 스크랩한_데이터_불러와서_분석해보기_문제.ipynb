# %% [markdown]
# <a href="https://colab.research.google.com/github/chacha86/BigData2/blob/colab/%EC%8A%A4%ED%81%AC%EB%9E%A9%ED%95%9C_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%88%EB%9F%AC%EC%99%80%EC%84%9C_%EB%B6%84%EC%84%9D%ED%95%B4%EB%B3%B4%EA%B8%B0_%EB%AC%B8%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# 1. json 파일을 이용해서 데이터프레임 만들기
file_path1 = '/content/KBS.json'
kbs = pd.read_json(file_path1, orient='records', encoding='utf-8-sig')

file_path2 = '/content/MBC.json'
mbc = pd.read_json(file_path2, orient='records', encoding='utf-8-sig')

file_path3 = '/content/SBS.json'
sbs = pd.read_json(file_path3, orient='records', encoding='utf-8-sig')

# %%
file_path4 = '/content/KBS_comment.json'
kbs_comm = pd.read_json(file_path4, orient='records', encoding='utf-8-sig')

file_path5 = '/content/MBC_comment.json'
mbc_comm = pd.read_json(file_path5,  orient='records', encoding='utf-8-sig')

file_path6 = '/content/SBS_comment.json'
sbs_comm = pd.read_json(file_path6, orient='records', encoding='utf-8-sig')

# %%
# concat
data1 = {
    '이름' : ['이순신', '홍길동', '황진이'],
    '수학' : [80, 90, 100],
    '영어' : [90, 80, 100],
    '국어' : [70, 100, 80]
}

data2 = {
    '이름' : ['이순신', '홍길동', '황진이'],
    '과학' : [80, 90, 100],
    '사회' : [90, 80, 100],
    '제2외국어' : [70, 100, 80]
}

data3 = {
    '이름' : ['이순신', '홍길동', '황진이', '유관순'],    
    '과학' : [80, 90, 100, 88],
    '사회' : [90, 80, 100, 92],
    '제2외국어' : [70, 100, 80, 76]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

print(df1)
print(df2)

pd.concat((df1, df2), axis=1)
# Out:
#     이름   수학   영어   국어
# 0  이순신   80   90   70
# 1  홍길동   90   80  100
# 2  황진이  100  100   80
#     이름   과학   사회  제2외국어
# 0  이순신   80   90     70
# 1  홍길동   90   80    100
# 2  황진이  100  100     80
#     이름   수학   영어   국어   이름   과학   사회  제2외국어
# 0  이순신   80   90   70  이순신   80   90     70
# 1  홍길동   90   80  100  홍길동   90   80    100
# 2  황진이  100  100   80  황진이  100  100     80

# %%
# 2. 같은 구조의 데이터 프레임 합치기 (concat)
all_news = pd.concat((kbs, mbc), ignore_index=True)
all_news = pd.concat((all_news, sbs), ignore_index=True)

all_comm = pd.concat((kbs_comm, mbc_comm), ignore_index=True)
all_comm = pd.concat((all_comm, sbs_comm), ignore_index=True)

# %%
all_news.head(5)

# 3. 다른 구조의 데이터 프레임 합치기 (merge)


# 4. 다양한 분석 시도.
# Out:
#    jid       nid                                     title  \
# 0   56  11290533  권성동 “국정원 1급 대기발령, 민주당의 잘못된 안보관 절연 위한 결단”
# 1   56  11290483    [여심야심] “나오지마” 면전 경고에도…이재명 ‘당권 도전’ 속내는?
# 2   56  11290532     대통령실 “노동시장 개혁은 대통령 지시사항”…엇박자 논란 재차 해명
# 3   56  11290514           ‘연 평균 676만 원’ 대학 등록금…14년 만에 인상?
# 4   56  11290518   이재명 “대책 없다고 손 놓으면 불안심리 더 악화…급한 불끄기 나서야”
#
#                                                 link
# 0  https://n.news.naver.com/article/056/001129053...
# 1  https://n.news.naver.com/article/056/001129048...
# 2  https://n.news.naver.com/article/056/001129053...
# 3  https://n.news.naver.com/article/056/001129051...
# 4  https://n.news.naver.com/article/056/001129051...

# %%
all_comm.head(5)

# 3. 다른 구조의 데이터 프레임 합치기 (merge)

# 4. 다양한 분석 시도.
# Out:
#          번호    댓글수   남자   여자 10대 20대  30대  40대  50대 60대↑
# 0  11290533  1,467  85%  15%  0%  1%   8%  30%  39%  22%
# 1  11290483  1,107  58%  42%  0%  5%  14%  30%  31%  20%
# 2  11290532    498  83%  17%  0%  1%  11%  38%  35%  14%
# 3  11290514    467  70%  30%  0%  7%  13%  43%  30%   6%
# 4  11290518    308  73%  27%  0%  3%  12%  41%  28%  15%

# %%
data1 = {
    'col1' : [1,2,3,4],
    'col2' : ['a','b','c','d'],
    'col3' : ['e','f','g','h']
}

data2 = {
    'col4' : [1,3,5,7],
    'col5' : ['i','j','k','l'],
    'col6' : ['m','n','o','p']
}

tdf1 = pd.DataFrame(data1)
tdf1

tdf2 = pd.DataFrame(data2)
tdf2

print(tdf1)
print(tdf2)

# how, on
# 
pd.merge(tdf1, tdf2, how='inner', left_on='col1', right_on='col4')
#pd.merge(tdf1, tdf2, how='outer', left_on='col1', right_on='col4')
#pd.merge(tdf1, tdf2, how='left', left_on='col1', right_on='col4')
#pd.merge(tdf1, tdf2, how='right', left_on='col1', right_on='col4')
# Out:
#    col1 col2 col3
# 0     1    a    e
# 1     2    b    f
# 2     3    c    g
# 3     4    d    h
#    col4 col5 col6
# 0     1    i    m
# 1     3    j    n
# 2     5    k    o
# 3     7    l    p
#    col1 col2 col3  col4 col5 col6
# 0   1.0    a    e     1    i    m
# 1   3.0    c    g     3    j    n
# 2   NaN  NaN  NaN     5    k    o
# 3   NaN  NaN  NaN     7    l    p

# %%
# 3. 다른 구조의 데이터 프레임 합치기 (merge)
all_news
all_comm

rst = pd.merge(all_news, all_comm, how='left', left_on='nid', right_on='번호')

rst = rst[['번호','link', '댓글수', '남자', '여자']]
rst
# 4. 다양한 분석 시도.

# 1. 20대가 가장 많이 본(댓글을 많이 작성한) 뉴스

# 2. 가장 댓글이 적은 뉴스의 댓글 수와 뉴스 링크, 뉴스 번호

# 3. 언론사 번호와 언론사 이름으로 구성된 데이터 프레임을 만들고 merge를 이용해 각 뉴스에 언론사 이름을 붙여주기

# 4. 각 언론사별 평균 댓글 수(댓글 수로 내림차순 정렬)

# 5. 여성의 댓글수가 가장 많은 언론사

# 6. 각 언론사 별 댓글을 많이 작성한 연령대 top3
# Out:
#             번호                                               link    댓글수   남자  \
# 0   11290533.0  https://n.news.naver.com/article/056/001129053...  1,467  85%
# 1   11290483.0  https://n.news.naver.com/article/056/001129048...  1,107  58%
# 2   11290532.0  https://n.news.naver.com/article/056/001129053...    498  83%
# 3   11290514.0  https://n.news.naver.com/article/056/001129051...    467  70%
# 4   11290518.0  https://n.news.naver.com/article/056/001129051...    308  73%
# 5    1204928.0  https://n.news.naver.com/article/214/000120492...  2,220  77%
# 6    1204953.0  https://n.news.naver.com/article/214/000120495...  1,002  69%
# 7    1204875.0  https://n.news.naver.com/article/214/000120487...  1,312  78%
# 8    1204980.0  https://n.news.naver.com/article/214/000120498...    703  80%
# 9    1204973.0  https://n.news.naver.com/article/214/000120497...    468  82%
# 10    981809.0  https://n.news.naver.com/article/055/000098180...  1,546  72%
# 11    981858.0  https://n.news.naver.com/article/055/000098185...  1,520  85%
# 12    981839.0  https://n.news.naver.com/article/055/000098183...    388  73%
# 13         NaN  https://n.news.naver.com/article/055/000098173...    NaN  NaN
# 14    981856.0  https://n.news.naver.com/article/055/000098185...    629  76%
#
#      여자  댓글수2
# 0   15%  1467
# 1   42%  1107
# 2   17%   498
# 3   30%   467
# 4   27%   308
# 5   23%  2220
# 6   31%  1002
# 7   22%  1312
# 8   20%   703
# 9   18%   468
# 10  28%  1546
# 11  15%  1520
# 12  27%   388
# 13  NaN     0
# 14  24%   629
